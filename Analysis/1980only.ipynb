# %%
import pandas as pd
import os
import numpy as np

# %%
pd.set_option('display.max_rows', 500)

# %%
df = pd.read_csv('Transcripts_1980.csv')

# %%
df
# Out:
#     Unnamed: 0  Unnamed: 0.1  Line Count  \
# 0         1296          1296           6
# 1         1299          1299           9
# 2         1302          1302          12
# 3         1305          1305          15
# 4         1307          1307          17
# 5         1309          1309          19
# 6         1312          1312          22
# 7         1315          1315          25
# 8         1318          1318          28
# 9         1321          1321          31
# 10        1323          1323          33
# 11        1325          1325          35
# 12        1327          1327          37
# 13        1330          1330          40
# 14        1333          1333          43
# 15        1336          1336          46
# 16        1339          1339          49
# 17        1341          1341          51
# 18        1343          1343          53
# 19        1346          1346          56
# 20        1349          1349          59
# 21        1352          1352          62
# ...

# %%
overallwordcount1980 = pd.Series(' '.join(df.Transcript).split()).value_counts()[:200]
overallwordcount1980
# Out:
# THE             1142
# OF               714
# TO               624
# THAT             616
# AND              562
# IN               495
# A                455
# I                395
# WE               263
# IS               257
# HAVE             227
# FOR              208
# THIS             182
# IT               171
# –                159
# WITH             147
# BE               133
# ARE              122
# WOULD            121
# OUR              119
# AS               116
# ON               107
# HAS              100
# BEEN              90
# THINK             87
# NOT               87
# WAS               82
# MR.               82
# OR                76
# THERE             73
# BUT               72
# BY                72
# YOU               71
# VERY              71
# HE                70
# THEY              70
# ONE               68
# GOVERNMENT        68
# ABOUT             67
# THOSE             66
# HAD               66
# PEOPLE            64
# BECAUSE           62
# ...

# %%
#Begin 1980 debates
#October 28, 1980
Oct28_1980_debate = df[df["Debate"]=='October 28, 1980 Debate Transcript']
Oct28_1980_debate
# Out:
#     Unnamed: 0  Unnamed: 0.1  Line Count                              Debate  \
# 0         1296          1296           6  October 28, 1980 Debate Transcript
# 1         1299          1299           9  October 28, 1980 Debate Transcript
# 2         1302          1302          12  October 28, 1980 Debate Transcript
# 3         1305          1305          15  October 28, 1980 Debate Transcript
# 4         1307          1307          17  October 28, 1980 Debate Transcript
# 5         1309          1309          19  October 28, 1980 Debate Transcript
# 6         1312          1312          22  October 28, 1980 Debate Transcript
# 7         1315          1315          25  October 28, 1980 Debate Transcript
# 8         1318          1318          28  October 28, 1980 Debate Transcript
# 9         1321          1321          31  October 28, 1980 Debate Transcript
# 10        1323          1323          33  October 28, 1980 Debate Transcript
# ...

# %%
#September 21, 1980 debate
Sept21_1980_debate = df[df["Debate"]=='September 21, 1980 Debate Transcript']
Sept21_1980_debate
# Out:
#     Unnamed: 0  Unnamed: 0.1  Line Count  \
# 52        3398          3398          11
# 53        3400          3400          13
# 54        3403          3403          16
# 55        3404          3404          17
# 56        3406          3406          19
# 57        3408          3408          21
# 58        3410          3410          23
# 59        3413          3413          26
# 60        3416          3416          29
# 61        3417          3417          30
# 62        3419          3419          32
# 63        3421          3421          34
# 64        3424          3424          37
# 65        3427          3427          40
# 66        3429          3429          42
# 67        3431          3431          44
# 68        3433          3433          46
# 69        3435          3435          48
# 70        3438          3438          51
# 71        3441          3441          54
# 72        3443          3443          56
# 73        3445          3445          58
# ...

# %%
debates_1980 = Oct28_1980_debate.append([Sept21_1980_debate])
debates_1980
# Out:
#     Unnamed: 0  Unnamed: 0.1  Line Count  \
# 0         1296          1296           6
# 1         1299          1299           9
# 2         1302          1302          12
# 3         1305          1305          15
# 4         1307          1307          17
# 5         1309          1309          19
# 6         1312          1312          22
# 7         1315          1315          25
# 8         1318          1318          28
# 9         1321          1321          31
# 10        1323          1323          33
# 11        1325          1325          35
# 12        1327          1327          37
# 13        1330          1330          40
# 14        1333          1333          43
# 15        1336          1336          46
# 16        1339          1339          49
# 17        1341          1341          51
# 18        1343          1343          53
# 19        1346          1346          56
# 20        1349          1349          59
# 21        1352          1352          62
# ...

# %%
overallwordcount1980 = pd.Series(' '.join(df.Transcript).split()).value_counts()[:200]

# %%
#for Carter/Dems 1980; no VP debate in 1980
Carter80 = debates_1980[(debates_1980["Speaker_standardized"]=='Jimmy Carter')]
Carter80
# Out:
#     Unnamed: 0  Unnamed: 0.1  Line Count                              Debate  \
# 2         1302          1302          12  October 28, 1980 Debate Transcript
# 3         1305          1305          15  October 28, 1980 Debate Transcript
# 5         1309          1309          19  October 28, 1980 Debate Transcript
# 6         1312          1312          22  October 28, 1980 Debate Transcript
# 7         1315          1315          25  October 28, 1980 Debate Transcript
# 10        1323          1323          33  October 28, 1980 Debate Transcript
# 11        1325          1325          35  October 28, 1980 Debate Transcript
# 15        1336          1336          46  October 28, 1980 Debate Transcript
# 16        1339          1339          49  October 28, 1980 Debate Transcript
# 18        1343          1343          53  October 28, 1980 Debate Transcript
# 19        1346          1346          56  October 28, 1980 Debate Transcript
# ...

# %%
#for Reagan/GOP in 1980, no VP debate
Reagan80 = debates_1980[(debates_1980["Speaker_standardized"]=='Ronald Reagan')]
Reagan80
# Out:
#     Unnamed: 0  Unnamed: 0.1  Line Count  \
# 0         1296          1296           6
# 1         1299          1299           9
# 4         1307          1307          17
# 8         1318          1318          28
# 9         1321          1321          31
# 12        1327          1327          37
# 13        1330          1330          40
# 14        1333          1333          43
# 17        1341          1341          51
# 21        1352          1352          62
# 22        1355          1355          65
# 24        1359          1359          69
# 25        1362          1362          72
# 28        1370          1370          80
# 31        1378          1378          88
# 33        1382          1382          92
# 35        1386          1386          96
# 36        1389          1389          99
# 38        1394          1394         104
# 40        1398          1398         108
# 43        1406          1406         116
# 45        1410          1410         120
# ...

# %%
#for Anderson/Ind. 1980, no VP debate in 1980
Anderson80 = debates_1980[(debates_1980["Speaker_standardized"]=='John B. Anderson')]
Anderson80
# Out:
#     Unnamed: 0  Unnamed: 0.1  Line Count  \
# 52        3398          3398          11
# 53        3400          3400          13
# 57        3408          3408          21
# 60        3416          3416          29
# 61        3417          3417          30
# 63        3421          3421          34
# 64        3424          3424          37
# 68        3433          3433          46
# 71        3441          3441          54
# 73        3445          3445          58
# 74        3448          3448          61
# 76        3453          3453          66
# 79        3463          3463          76
# 81        3467          3467          80
# 83        3471          3471          84
#
#                                   Debate  \
# 52  September 21, 1980 Debate Transcript
# 53  September 21, 1980 Debate Transcript
# 57  September 21, 1980 Debate Transcript
# 60  September 21, 1980 Debate Transcript
# 61  September 21, 1980 Debate Transcript
# 63  September 21, 1980 Debate Transcript
# ...

# %%
allcandidates80 = Anderson80.append([Reagan80, Carter80]) 
allcandidates80
# Out:
#     Unnamed: 0  Unnamed: 0.1  Line Count  \
# 52        3398          3398          11
# 53        3400          3400          13
# 57        3408          3408          21
# 60        3416          3416          29
# 61        3417          3417          30
# 63        3421          3421          34
# 64        3424          3424          37
# 68        3433          3433          46
# 71        3441          3441          54
# 73        3445          3445          58
# 74        3448          3448          61
# 76        3453          3453          66
# 79        3463          3463          76
# 81        3467          3467          80
# 83        3471          3471          84
# 0         1296          1296           6
# 1         1299          1299           9
# 4         1307          1307          17
# 8         1318          1318          28
# 9         1321          1321          31
# 12        1327          1327          37
# 13        1330          1330          40
# ...

# %%
allcandidates80_nuclear = allcandidates80.Transcript.str.count('NUCLEAR')
allcandidates80_nuclear.sum()
# Out:
# 25

# %%
allcandidates80_atomic = allcandidates80.Transcript.str.count('ATOMIC')
allcandidates80_atomic.sum()
# Out:
# 5

# %%
allcandidates80_proliferation = allcandidates80.Transcript.str.count('PROLIFERATION')
allcandidates80_proliferation.sum()
# Out:
# 4

# %%
allcandidates80_nonproliferation = allcandidates80.Transcript.str.count('NONPROLIFERATION')
allcandidates80_nonproliferation.sum()
# Out:
# 0

# %%
allcandidates80_non_proliferation = allcandidates80.Transcript.str.count('NON-PROLIFERATION')
allcandidates80_non_proliferation.sum()
# Out:
# 1

# %%
allcandidates80_women = allcandidates80.Transcript.str.count('WOMEN')
allcandidates80_women.sum()
# Out:
# 21

# %%
allcandidates80_job = allcandidates80.Transcript.str.count('JOB')
allcandidates80_job.sum()
# Out:
# 29

# %%
allcandidates80_jobs = allcandidates80.Transcript.str.count('JOBS')
allcandidates80_jobs.sum()
# Out:
# 23

# %%
allcandidates80_unemployment = allcandidates80.Transcript.str.count('UNEMPLOYMENT')
allcandidates80_unemployment.sum()
# Out:
# 17

# %%
allcandidates80_foreign = allcandidates80.Transcript.str.count('FOREIGN')
allcandidates80_foreign.sum()
# Out:
# 7

# %%
allcandidates80_world = allcandidates80.Transcript.str.count('WORLD')
allcandidates80_world.sum()
# Out:
# 32

# %%
allcandidates80_Iraq = allcandidates80.Transcript.str.count('IRAQ')
allcandidates80_Iraq.sum()
# Out:
# 3

# %%
allcandidates80_Soviet = allcandidates80.Transcript.str.count('SOVIET')
allcandidates80_Soviet.sum()
# Out:
# 12

# %%
allcandidates80_Soviets = allcandidates80.Transcript.str.count('SOVIETS')
allcandidates80_Soviets.sum()
# Out:
# 0

# %%
allcandidates80_Russia = allcandidates80.Transcript.str.count('RUSSIA')
allcandidates80_Russia.sum()
# Out:
# 0
