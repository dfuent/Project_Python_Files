# %%
import pandas as pd
import os
import numpy as np

# %%
df = pd.read_csv('Transcripts_2020.csv')

# %%
df
# Out:
#       Unnamed: 0  Unnamed: 0.1  Affiliation                     Debate  \
# 0          14271             2          NaN  September 29, 2020 Debate
# 1          14272             3          NaN  September 29, 2020 Debate
# 2          14273             4          NaN  September 29, 2020 Debate
# 3          14275             6          NaN  September 29, 2020 Debate
# 4          14276             7          NaN  September 29, 2020 Debate
# ...          ...           ...          ...                        ...
# 1089       15889          1620          NaN     October 7, 2020 Debate
# 1090       15891          1622          NaN     October 7, 2020 Debate
# 1091       15892          1623          NaN     October 7, 2020 Debate
# 1092       15893          1624          NaN     October 7, 2020 Debate
# 1093       15894          1625          NaN     October 7, 2020 Debate
#
#       Line Count        Position    Purpose              Speaker_Clean  \
# ...

# %%
print(df['Speaker_standardized'].unique())
# Out:
# ['Vice President Joe Biden' 'President Donald J. Trump' 'Donald Trump'
#  'Joe Biden' 'Kamala Harris' 'Mike Pence' 'Kamala Harris ']

# %%
#Trump2020
Trump20a = df[(df['Speaker_standardized']=='President Donald J. Trump')]
Trump20a

Trump20b = df[(df['Speaker_standardized']=='Donald Trump')]
Trump20b

#Trump overall 2020
Trump20all = Trump20a.append([Trump20b]) 
Trump20all
# Out:
#      Unnamed: 0  Unnamed: 0.1  Affiliation                     Debate  \
# 1         14272             3          NaN  September 29, 2020 Debate
# 3         14275             6          NaN  September 29, 2020 Debate
# 4         14276             7          NaN  September 29, 2020 Debate
# 6         14279            10          NaN  September 29, 2020 Debate
# 10        14283            14          NaN  September 29, 2020 Debate
# ..          ...           ...          ...                        ...
# 879       15558          1289          NaN    October 22, 2020 Debate
# 881       15561          1292          NaN    October 22, 2020 Debate
# 882       15563          1294          NaN    October 22, 2020 Debate
# 883       15564          1295          NaN    October 22, 2020 Debate
# 884       15565          1296          NaN    October 22, 2020 Debate
#
#      Line Count   Position    Purpose              Speaker_Clean  \
# ...

# %%
#Pence2020
Pence20 = df[(df["Speaker_standardized"]=='Mike Pence')]
Pence20
# Out:
#       Unnamed: 0  Unnamed: 0.1  Affiliation                  Debate  \
# 891        15578          1309          NaN  October 7, 2020 Debate
# 892        15579          1310          NaN  October 7, 2020 Debate
# 893        15581          1312          NaN  October 7, 2020 Debate
# 894        15583          1314          NaN  October 7, 2020 Debate
# 897        15588          1319          NaN  October 7, 2020 Debate
# ...          ...           ...          ...                     ...
# 1085       15884          1615          NaN  October 7, 2020 Debate
# 1086       15885          1616          NaN  October 7, 2020 Debate
# 1087       15886          1617          NaN  October 7, 2020 Debate
# 1088       15888          1619          NaN  October 7, 2020 Debate
# 1089       15889          1620          NaN  October 7, 2020 Debate
#
#       Line Count        Position    Purpose Speaker_Clean  \
# 891          NaN  Vice President  Candidate    Mike Pence
# ...

# %%
#Biden2020
Biden20a = df[(df["Speaker_standardized"]=='Vice President Joe Biden')]
Biden20a

Biden20b = df[(df["Speaker_standardized"]=='Joe Biden')]
Biden20b

Biden20all=Biden20a.append([Biden20b]) 
Biden20all
# Out:
#      Unnamed: 0  Unnamed: 0.1  Affiliation                     Debate  \
# 0         14271             2          NaN  September 29, 2020 Debate
# 2         14273             4          NaN  September 29, 2020 Debate
# 5         14278             9          NaN  September 29, 2020 Debate
# 7         14280            11          NaN  September 29, 2020 Debate
# 8         14281            12          NaN  September 29, 2020 Debate
# ..          ...           ...          ...                        ...
# 877       15554          1285          NaN    October 22, 2020 Debate
# 880       15560          1291          NaN    October 22, 2020 Debate
# 885       15567          1298          NaN    October 22, 2020 Debate
# 886       15568          1299          NaN    October 22, 2020 Debate
# 887       15570          1301          NaN    October 22, 2020 Debate
#
#      Line Count   Position    Purpose             Speaker_Clean  \
# ...

# %%
#Harris2020
Harris20a = df[(df["Speaker_standardized"]=='Kamala Harris')]
Harris20a

Harris20b = df[(df["Speaker_standardized"]=='Kamala Harris ')]
Harris20b

Harris20all=Harris20a.append([Harris20b]) 
Harris20all
# Out:
#       Unnamed: 0  Unnamed: 0.1  Affiliation                  Debate  \
# 888        15573          1304          NaN  October 7, 2020 Debate
# 889        15574          1305          NaN  October 7, 2020 Debate
# 890        15576          1307          NaN  October 7, 2020 Debate
# 895        15585          1316          NaN  October 7, 2020 Debate
# 896        15587          1318          NaN  October 7, 2020 Debate
# ...          ...           ...          ...                     ...
# 1084       15882          1613          NaN  October 7, 2020 Debate
# 1090       15891          1622          NaN  October 7, 2020 Debate
# 1091       15892          1623          NaN  October 7, 2020 Debate
# 1092       15893          1624          NaN  October 7, 2020 Debate
# 1093       15894          1625          NaN  October 7, 2020 Debate
#
#       Line Count        Position    Purpose   Speaker_Clean  \
# 888          NaN  Vice President  Candidate   Kamala Harris
# ...

# %%
len(Harris20all)
# Out:
# 94

# %%
GOP20 = Trump20all.append([Pence20])
GOP20
# Out:
#       Unnamed: 0  Unnamed: 0.1  Affiliation                     Debate  \
# 1          14272             3          NaN  September 29, 2020 Debate
# 3          14275             6          NaN  September 29, 2020 Debate
# 4          14276             7          NaN  September 29, 2020 Debate
# 6          14279            10          NaN  September 29, 2020 Debate
# 10         14283            14          NaN  September 29, 2020 Debate
# ...          ...           ...          ...                        ...
# 1085       15884          1615          NaN     October 7, 2020 Debate
# 1086       15885          1616          NaN     October 7, 2020 Debate
# 1087       15886          1617          NaN     October 7, 2020 Debate
# 1088       15888          1619          NaN     October 7, 2020 Debate
# 1089       15889          1620          NaN     October 7, 2020 Debate
#
#       Line Count        Position    Purpose              Speaker_Clean  \
# ...

# %%
Dem20 = Harris20all.append([Biden20all]) 
Dem20
# Out:
#      Unnamed: 0  Unnamed: 0.1  Affiliation                   Debate  \
# 888       15573          1304          NaN   October 7, 2020 Debate
# 889       15574          1305          NaN   October 7, 2020 Debate
# 890       15576          1307          NaN   October 7, 2020 Debate
# 895       15585          1316          NaN   October 7, 2020 Debate
# 896       15587          1318          NaN   October 7, 2020 Debate
# ..          ...           ...          ...                      ...
# 877       15554          1285          NaN  October 22, 2020 Debate
# 880       15560          1291          NaN  October 22, 2020 Debate
# 885       15567          1298          NaN  October 22, 2020 Debate
# 886       15568          1299          NaN  October 22, 2020 Debate
# 887       15570          1301          NaN  October 22, 2020 Debate
#
#      Line Count        Position    Purpose  Speaker_Clean  \
# 888         NaN  Vice President  Candidate  Kamala Harris
# ...

# %%
GOP20_nuclear = GOP20.Transcript.str.count('NUCLEAR')
GOP20_nuclear.sum()
# Out:
# 3

# %%
Dem20_nuclear = Dem20.Transcript.str.count('NUCLEAR')
Dem20_nuclear.sum()
# Out:
# 7

# %%
GOP20_atomic = GOP20.Transcript.str.count('ATOMIC')
GOP20_atomic.sum()
# Out:
# 0

# %%
Dem20_atomic = Dem20.Transcript.str.count('ATOMIC')
Dem20_atomic.sum()
# Out:
# 0

# %%
GOP20_proliferation = GOP20.Transcript.str.count('PROLIFERATION')
GOP20_proliferation.sum()
# Out:
# 0

# %%
Dem20_proliferation = Dem20.Transcript.str.count('PROLIFERATION')
Dem20_proliferation.sum()
# Out:
# 0

# %%
GOP20_nonproliferation = GOP20.Transcript.str.count('NONPROLIFERATION')
GOP20_nonproliferation.sum()
# Out:
# 0

# %%
Dem20_nonproliferation = Dem20.Transcript.str.count('NONPROLIFERATION')
Dem20_nonproliferation.sum()
# Out:
# 0

# %%
GOP20_non_proliferation = GOP20.Transcript.str.count('NON-PROLIFERATION')
GOP20_non_proliferation.sum()
# Out:
# 0

# %%
Dem20_non_proliferation = Dem20.Transcript.str.count('NON-PROLIFERATION')
Dem20_non_proliferation.sum()
# Out:
# 0

# %%
GOP20_armsrace = GOP20.Transcript.str.count('ARMS RACE')
GOP20_armsrace.sum()
# Out:
# 0

# %%
Dem20_armsrace = Dem20.Transcript.str.count('ARMS RACE')
Dem20_armsrace.sum()
# Out:
# 0

# %%
GOP20_women = GOP20.Transcript.str.count('WOMEN')
GOP20_women.sum()
# Out:
# 5

# %%
Dem20_women = Dem20.Transcript.str.count('WOMEN')
Dem20_women.sum()
# Out:
# 4

# %%
GOP20_job = GOP20.Transcript.str.count('JOB')
GOP20_job.sum()
# Out:
# 38

# %%
Dem20_job = Dem20.Transcript.str.count('JOB')
Dem20_job.sum()
# Out:
# 43

# %%
GOP20_jobs = GOP20.Transcript.str.count('JOBS')
GOP20_jobs.sum()
# Out:
# 19

# %%
Dem20_jobs = Dem20.Transcript.str.count('JOBS')
Dem20_jobs.sum()
# Out:
# 32

# %%
GOP20_unemployment = GOP20.Transcript.str.count('UNEMPLOYMENT')
GOP20_unemployment.sum()
# Out:
# 3

# %%
Dem20_unemployment = Dem20.Transcript.str.count('UNEMPLOYMENT')
Dem20_unemployment.sum()
# Out:
# 1

# %%
GOP20_world = GOP20.Transcript.str.count('WORLD')
GOP20_world.sum()
# Out:
# 19

# %%
Dem20_world = Dem20.Transcript.str.count('WORLD')
Dem20_world.sum()
# Out:
# 14

# %%
GOP20_foreign = GOP20.Transcript.str.count('FOREIGN')
GOP20_foreign.sum()
# Out:
# 0

# %%
Dem20_foreign = Dem20.Transcript.str.count('FOREIGN')
Dem20_foreign.sum()
# Out:
# 6

# %%
nuclear = df.Transcript.str.count('NUCLEAR') 
nuclear.sum()
# Out:
# 10

# %%
atomic = df.Transcript.str.count('ATOMIC') 
atomic.sum()
# Out:
# 0

# %%
proliferation = df.Transcript.str.count('PROLIFERATION') 
proliferation.sum()
# Out:
# 0

# %%
nonproliferation = df.Transcript.str.count('NONPROLIFERATION') 
nonproliferation.sum()
# Out:
# 0

# %%
non_proliferation = df.Transcript.str.count('NON-PROLIFERATION') 
non_proliferation.sum()
# Out:
# 0

# %%
armsrace = df.Transcript.str.count('ARMS RACE') 
armsrace.sum()
# Out:
# 0

# %%
women = df.Transcript.str.count('WOMEN') 
women.sum()
# Out:
# 9

# %%
job = df.Transcript.str.count('JOB') 
job.sum()
# Out:
# 81

# %%
jobs = df.Transcript.str.count('JOBS') 
jobs.sum()
# Out:
# 51

# %%
unemployment = df.Transcript.str.count('UNEMPLOYMENT') 
unemployment.sum()
# Out:
# 4

# %%
world = df.Transcript.str.count('WORLD') 
world.sum()
# Out:
# 33

# %%
foreign = df.Transcript.str.count('FOREIGN') 
foreign.sum()
# Out:
# 6
